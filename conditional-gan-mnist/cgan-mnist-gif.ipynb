# %%
import os
import imageio

# Directory where the images are stored
image_folder = "images-mnist-cgan"

# Output GIF file path
output_file = 'generated.gif'

# Create a list of image files in the directory
images = []
for filename in os.listdir(image_folder):
    if filename.endswith('.png'):
        images.append(imageio.imread(os.path.join(image_folder, filename)))

# Save images as a GIF
imageio.mimsave(output_file, images, duration=0.5)  

print(f'Generated GIF saved as {output_file}')
# Out:
# C:\Users\shory\AppData\Local\Temp\ipykernel_13780\3034309122.py:14: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   images.append(imageio.imread(os.path.join(image_folder, filename)))
# Generated GIF saved as generated.gif

# %%
from IPython.display import Image, display

display(Image(filename=output_file))
